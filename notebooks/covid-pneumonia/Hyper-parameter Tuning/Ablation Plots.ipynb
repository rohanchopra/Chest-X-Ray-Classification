# %%
import os
os.environ["KMP_DUPLICATE_LIB_OK"]="TRUE"

# %%
import pickle
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import confusion_matrix, f1_score

# %%
model_name = ["resnet34", "mobile_net_v3_large", "efficient_net_b1"]
dataset_name = "covid_pneumonia"
num_epochs = "100"

# %% [markdown]
# # Covid Pneumonia

# %%
dataset_name = "covid_pneumonia"

# %% [markdown]
# ### Learning Rates

# %%
l_rates = [0.005, 0.001, 0.05, 0.01, 0.1]

# %% [markdown]
# ## Efficient Net (LR=0.005)

# %%
curr_model = "efficient_net_b1"
curr_LR = l_rates[0]
batch_size = "32"

train_LR1_loss = {}
val_LR1_loss = {}

# val_LR1_acc = {}
# val_LR1_true = {}
# val_LR1_pred = {}
# train_LR1_acc = {}
# train_LR1_true = {}
# train_LR1_pred = {}

# %%
with open(f'../../models/hyper_parameter/{l_rates[0]}_val_history_{curr_model}_{dataset_name}_{num_epochs}_{batch_size}_0.005_0.0005_.pickle', 'rb') as handle:
    val_LR1 = pickle.load(handle)

# %%
loss_val_LR1 = val_LR1['loss']

# %%
with open(f'../../models/hyper_parameter/{l_rates[0]}_train_history_{curr_model}_{dataset_name}_{num_epochs}_{batch_size}_0.005_0.0005_.pickle', 'rb') as handle:
    train_LR1 = pickle.load(handle)

# %%
loss_train_LR1 = train_LR1['loss']

# %%
# Validation F1-score
i_iter=0
f1score_val_LR1 = []
for i in val_LR1['targets']:
    f1score_val_LR1.append(f1_score(val_LR1['targets'][i_iter], val_LR1['outputs'][i_iter], average='macro'))
    i_iter=i_iter+1

f1score_val_LR1[99]
# Out:
# 0.9739599351715528

# %%
# Training F1-score
i_iter=0
f1score_train_LR1 = []
for i in train_LR1['targets']:
    f1score_train_LR1.append(f1_score(train_LR1['targets'][i_iter], train_LR1['outputs'][i_iter], average='macro'))
    i_iter=i_iter+1

f1score_train_LR1[98]
# Out:
# 1.0

# %% [markdown]
# ## Efficient Net (LR=0.001)

# %%
curr_model = "efficient_net_b1"
curr_LR = l_rates[1]
batch_size = "32"

train_LR1_loss = {}
val_LR1_loss = {}

# val_LR1_acc = {}
# val_LR1_true = {}
# val_LR1_pred = {}
# train_LR1_acc = {}
# train_LR1_true = {}
# train_LR1_pred = {}

# %%
with open(f'../../models/hyper_parameter/{l_rates[1]}_val_history_{curr_model}_{dataset_name}_{num_epochs}_{batch_size}_0.001_0.0001_.pickle', 'rb') as handle:
    val_LR2 = pickle.load(handle)

# %%
loss_val_LR2 = val_LR2['loss']

# %%
with open(f'../../models/hyper_parameter/{l_rates[1]}_train_history_{curr_model}_{dataset_name}_{num_epochs}_{batch_size}_0.001_0.0001_.pickle', 'rb') as handle:
    train_LR2 = pickle.load(handle)

# %%
loss_train_LR2 = train_LR2['loss']

# %%
# Validation F1-score
i_iter=0
f1score_val_LR2 = []
for i in val_LR2['targets']:
    f1score_val_LR2.append(f1_score(val_LR2['targets'][i_iter], val_LR2['outputs'][i_iter], average='macro'))
    i_iter=i_iter+1

f1score_val_LR2[99]
# Out:
# 0.9775555619711463

# %%
# Training F1-score
i_iter=0
f1score_train_LR2 = []
for i in train_LR2['targets']:
    f1score_train_LR2.append(f1_score(train_LR2['targets'][i_iter], train_LR2['outputs'][i_iter], average='macro'))
    i_iter=i_iter+1

f1score_train_LR2[99]
# Out:
# 1.0

# %% [markdown]
# ## Efficient Net (LR=0.05)

# %%
curr_model = "efficient_net_b1"
curr_LR = l_rates[2]
batch_size = "32"

train_LR1_loss = {}
val_LR1_loss = {}

# val_LR1_acc = {}
# val_LR1_true = {}
# val_LR1_pred = {}
# train_LR1_acc = {}
# train_LR1_true = {}
# train_LR1_pred = {}

# %%
with open(f'../../models/hyper_parameter/{l_rates[2]}_val_history_{curr_model}_{dataset_name}_{num_epochs}_{batch_size}_0.05_0.005_.pickle', 'rb') as handle:
    val_LR3 = pickle.load(handle)

# %%
loss_val_LR3 = val_LR3['loss']

# %%
with open(f'../../models/hyper_parameter/{l_rates[2]}_train_history_{curr_model}_{dataset_name}_{num_epochs}_{batch_size}_0.05_0.005_.pickle', 'rb') as handle:
    train_LR3 = pickle.load(handle)

# %%
loss_train_LR3 = train_LR3['loss']

# %%
# Validation F1-score
i_iter=0
f1score_val_LR3 = []
for i in val_LR3['targets']:
    f1score_val_LR3.append(f1_score(val_LR3['targets'][i_iter], val_LR3['outputs'][i_iter], average='macro'))
    i_iter=i_iter+1

f1score_val_LR3[99]
# Out:
# 0.9560670073319923

# %%
# Training F1-score
i_iter=0
f1score_train_LR3 = []
for i in train_LR3['targets']:
    f1score_train_LR3.append(f1_score(train_LR3['targets'][i_iter], train_LR3['outputs'][i_iter], average='macro'))
    i_iter=i_iter+1

f1score_train_LR3[99]
# Out:
# 0.9985922805557933

# %% [markdown]
# ## Efficient Net (LR=0.01)

# %%
curr_model = "efficient_net_b1"
curr_LR = l_rates[3]
batch_size = "32"

train_LR1_loss = {}
val_LR1_loss = {}

# val_LR1_acc = {}
# val_LR1_true = {}
# val_LR1_pred = {}
# train_LR1_acc = {}
# train_LR1_true = {}
# train_LR1_pred = {}

# %%
with open(f'../../models/hyper_parameter/{l_rates[3]}_val_history_{curr_model}_{dataset_name}_{num_epochs}_{batch_size}_0.01_0.001_.pickle', 'rb') as handle:
    val_LR4 = pickle.load(handle)

# %%
loss_val_LR4 = val_LR4['loss']

# %%
with open(f'../../models/hyper_parameter/{l_rates[3]}_train_history_{curr_model}_{dataset_name}_{num_epochs}_{batch_size}_0.01_0.001_.pickle', 'rb') as handle:
    train_LR4 = pickle.load(handle)

# %%
loss_train_LR4 = train_LR4['loss']

# %%
# Validation F1-score
i_iter=0
f1score_val_LR4 = []
for i in val_LR4['targets']:
    f1score_val_LR4.append(f1_score(val_LR4['targets'][i_iter], val_LR4['outputs'][i_iter], average='macro'))
    i_iter=i_iter+1

f1score_val_LR4[99]
# Out:
# 0.9783348342011428

# %%
# Training F1-score
i_iter=0
f1score_train_LR4 = []
for i in train_LR4['targets']:
    f1score_train_LR4.append(f1_score(train_LR4['targets'][i_iter], train_LR4['outputs'][i_iter], average='macro'))
    i_iter=i_iter+1

f1score_train_LR4[99]
# Out:
# 1.0

# %% [markdown]
# ## Efficient Net (LR=0.1)

# %%
curr_model = "efficient_net_b1"
curr_LR = l_rates[4]
batch_size = "32"

train_LR1_loss = {}
val_LR1_loss = {}

# val_LR1_acc = {}
# val_LR1_true = {}
# val_LR1_pred = {}
# train_LR1_acc = {}
# train_LR1_true = {}
# train_LR1_pred = {}

# %%
with open(f'../../models/hyper_parameter/{l_rates[4]}_val_history_{curr_model}_{dataset_name}_{num_epochs}_{batch_size}_0.1_0.01_.pickle', 'rb') as handle:
    val_LR5 = pickle.load(handle)

# %%
loss_val_LR5 = val_LR5['loss']

# %%
with open(f'../../models/hyper_parameter/{l_rates[4]}_train_history_{curr_model}_{dataset_name}_{num_epochs}_{batch_size}_0.1_0.01_.pickle', 'rb') as handle:
    train_LR5 = pickle.load(handle)

# %%
loss_train_LR5 = train_LR5['loss']

# %%
# Validation F1-score
i_iter=0
f1score_val_LR5 = []
for i in val_LR5['targets']:
    f1score_val_LR5.append(f1_score(val_LR5['targets'][i_iter], val_LR5['outputs'][i_iter], average='macro'))
    i_iter=i_iter+1

f1score_val_LR5[99]
# Out:
# 0.9398689682461484

# %%
# Training F1-score
i_iter=0
f1score_train_LR5 = []
for i in train_LR5['targets']:
    f1score_train_LR5.append(f1_score(train_LR5['targets'][i_iter], train_LR5['outputs'][i_iter], average='macro'))
    i_iter=i_iter+1

f1score_train_LR5[99]
# Out:
# 0.997822179406887

# %% [markdown]
# ## Making Model Params

# %%
metric_params = { "f1_score": {'f1score_val_LR1': f1score_val_LR1, 'f1score_train_LR1': f1score_train_LR1,
                               'f1score_val_LR2': f1score_val_LR2, 'f1score_train_LR2': f1score_train_LR2,
                               'f1score_val_LR3': f1score_val_LR3, 'f1score_train_LR3': f1score_train_LR3,
                               'f1score_val_LR4': f1score_val_LR4, 'f1score_train_LR4': f1score_train_LR4,
                              'f1score_val_LR5': f1score_val_LR5, 'f1score_train_LR5': f1score_train_LR5
                              },
                   "loss":   { 'loss_val_LR1': loss_val_LR1, 'loss_train_LR1': loss_train_LR1,
                               'loss_val_LR2': loss_val_LR2, 'loss_train_LR2': loss_train_LR2,
                               'loss_val_LR3': loss_val_LR3, 'loss_train_LR3': loss_train_LR3,
                               'loss_val_LR4': loss_val_LR4, 'loss_train_LR4': loss_train_LR4,
                               'loss_val_LR5': loss_val_LR5, 'loss_train_LR5': loss_train_LR5
                             }
                }

# %%
metric_name = ['f1_score', 'loss']

# %%
import pprint
pp = pprint.PrettyPrinter(depth=10)
pp.pprint(metric_params)
# Out:
# {'f1_score': {'f1score_train_LR1': [0.5647504998319879,
#                                     0.6287530483397087,
#                                     0.7094438239216698,
#                                     0.772584331565112,
#                                     0.8187050351599726,
#                                     0.8526062395868762,
#                                     0.8770297637697833,
#                                     0.8941775886043689,
#                                     0.911195240312359,
#                                     0.9165365023283393,
#                                     0.9227107691344337,
#                                     0.9323250266026902,
#                                     0.9343609991014935,
#                                     0.9423595455613633,
#                                     0.9468840174229854,
#                                     0.9506497046223624,
#                                     0.9543436767499069,
#                                     0.9573328219578375,
#                                     0.9576786945710177,
#                                     0.9608260294567413,
#                                     0.9627501869040569,
#                                     0.9651109045394497,
#                                     0.9648002756898592,
#                                     0.9698552283218879,
#                                     0.9677902087276419,
#                                     0.9732669501118107,
#                                     0.971848035452955,
#                                     0.9735946814812916,
#                                     0.9713383420022267,
#                                     0.9755446916677832,
#                                     0.9805400568807859,
#                                     0.9802385414877257,
#                                     0.9803176366475753,
#                                     0.9805034015516432,
#                                     0.9842601167042084,
#                                     0.978342198050413,
#                                     0.9860413296996619,
#                                     0.9872286062750165,
#                                     0.9840995124831116,
#                                     0.984106081424303,
#                                     0.9874279050055019,
#                                     0.9808801714238508,
#                                     0.9908928642304597,
#                                     0.989752501150332,
#                                     0.9878281498622045,
#                                     0.9902866416405511,
#                                     0.9888893086366081,
#                                     0.9915927741183016,
#                                     0.9889913092290402,
#                                     0.9893215107632796,
#                                     0.9926493360745541,
#                                     0.9951786908777306,
#                                     0.9905173867212299,
#                                     0.9943192116114039,
#                            3661050.9620230757,
#                            561623.7096643242,
#                            2988571.0374173764,
#                            0.4800491387453939,
#                            0.3979746618375697,
#                            0.2273635897371504,
#                            52577.990192219775,
#                            4009136.3033527955,
#                            0.23182395285555532,
#                            0.22367819807931444,
#                            187957830.9933684,
#                            0.31524379444022743,
#                            0.2222099755749558,
#                            28097312.683110982,
#                            2166173.9969639326,
#                            0.2176000899892147,
#                            0.200526996190054,
#                            0.22500148293121358,
#                            0.2730008206202156,
#                            562209462.2842653,
#                            0.24673285001126155,
#                            0.24969847460445557,
#                            0.2712909295462454,
#                            424.81670043956984,
#                            0.40301441684552153,
#                            0.29497801664027745,
#                            13059926088.046825,
#                            570500952277.7513,
#                            0.37085505471811864,
#                            20083230.99645501,
#                            0.28247348221254814,
#                            0.33614047790235074,
#                            0.23872819894812777,
#                            0.24632346662307952,
#                            0.2654777610733839,
#                            0.22139911928532352,
#                            0.23144837811493993,
#                            0.3573354861621695,
#                            0.3712353649356156,
#                            0.37926978092545116,
#                            0.27241984453884827,
#                            0.29342623689973896,
#                            0.295867606278893,
#                            0.24424717695696818,
#                            0.23377444948473722,
#                            0.30913221216221465,
#                            0.22793305640940345,
#                            0.24208077290905863,
#                            0.3157712321128934,
#                            0.2808687422408635,
#                            0.2579094725193993,
#                            0.26222152275806265,
#                            0.32442931204962977,
#                            0.3563725780088556,
#                            0.303405443429344,
#                            0.2723523713185191,
#                            0.30677134470881895,
#                            0.3393838504358631,
#                            0.29053008750029685,
#                            0.3020926435509148,
#                            0.33323940049738227,
#                            0.3249146562299772,
#                            0.30051129081549893,
#                            0.2934533129817073]}}

# %% [markdown]
# ## Plottling LRs

# %%
plot_names = ['F1 Plot', 'Loss Plot']

colors_f1_score = {'f1score_train_LR1': 'tab:red', 'f1score_val_LR1': 'tab:red', 
                   'f1score_train_LR2': 'tab:green', 'f1score_val_LR2': 'tab:green',
                   'f1score_train_LR3': 'tab:orange', 'f1score_val_LR3': 'tab:orange',
                   'f1score_train_LR4': 'tab:blue', 'f1score_val_LR4': 'tab:blue',
                   'f1score_train_LR5': 'tab:grey', 'f1score_val_LR5': 'tab:grey'
                  }

colors_loss = {'loss_train_LR1': 'firebrick', 'loss_val_LR1': 'firebrick',  
               'loss_train_LR2': 'chocolate', 'loss_val_LR2': 'chocolate',
               'loss_train_LR3': 'peru', 'loss_val_LR3': 'peru',
               'loss_train_LR4': 'forestgreen', 'loss_val_LR4': 'forestgreen',
               'loss_train_LR5': 'tab:purple', 'loss_val_LR5': 'tab:purple'
              }

l_rates = [0.005, 0.001, 0.05, 0.01, 0.1]

# %%
## F1 for train and val                                                                Loss for train and val

fig = plt.figure(figsize=(16, 10))
gs = fig.add_gridspec(2, 2, hspace=0, wspace=0)
ax1 = gs.subplots(sharex='col', sharey='row')

fig.suptitle(f'Train and Validation - F1 Score and Loss Plots', fontsize=16)

epochs = [i for i in range(int(num_epochs))]

hand = []
lab = []


#plot = plot_names[i]
#ax1[i].set_title(f'{plot}')
for j in range(5):

    ax1[0][0].plot(epochs, metric_params['f1_score'][f'f1score_train_LR{j+1}'],
                    label = f'LR = {l_rates[j]}-F1 Score (Train)', 
                    color = colors_f1_score[f'f1score_train_LR{j+1}']
                    )
    ax1[0][0].set_xlabel('Loss Plot')
    ax1[0][0].set_ylabel('F1 Score')
    ax1[0][0].set_title("Training")
    #ax1[0][0].legend(bbox_to_anchor=(0.5, -1.05, 0.40, 0.94))

    ax1[0][1].plot(epochs, metric_params['f1_score'][f'f1score_val_LR{j+1}'],
                    label = f'LR = {l_rates[j]}-F1 Score (Val)', 
                    color = colors_f1_score[f'f1score_val_LR{j+1}']
                    )
    ax1[0][1].set_title("Validation")
    #ax1[0][1].legend(bbox_to_anchor=(0.5, -1.05, 0.40, 0.94))



for j in range(5):
    ax1[1][0].plot(epochs, np.log(metric_params['loss'][f'loss_train_LR{j+1}']),
                    label = f'LR = {l_rates[j]}-Loss (Train)', 
                    color = colors_loss[f'loss_train_LR{j+1}']
                    )
    ax1[1][0].set_ylabel('Loss (Log Scale)')
    ax1[1][0].set_xlabel('Epochs')
    #ax1[1][0].legend(bbox_to_anchor=(0.5, -1.05, 0.40, 0.94))

    ax1[1][1].plot(epochs, np.log(metric_params['loss'][f'loss_val_LR{j+1}']),
                    label = f'LR = {l_rates[j]}-Loss (Val)', 
                    color = colors_loss[f'loss_val_LR{j+1}']
                    )
    ax1[1][1].set_xlabel('Epochs')
    #ax1[1][1].legend(bbox_to_anchor=(0.5, -1.05, 0.40, 0.94))
    #ax1[1][1].legend(bbox_to_anchor=(0, -1.05, 0.40, 0.94))
        
    # for k in range(2):
    #     handles, labels = ax1[i][k].get_legend_handles_labels()
    #     hand.append(handles)
    #     lab.append(labels)
        

# handles_labels = [ax.get_legend_handles_labels() for ax in fig.axes]
# handles, labels = [sum(handles_and_labels, []) for handles_and_labels in zip(*lines_labels)]
# plt.legend(handles, labels, bbox_to_anchor=(0.5, -1.05, 0.40, 0.94))

ax1[0][0].legend(bbox_to_anchor=(0.4, -1.15, 0, 0))
ax1[1][0].legend(bbox_to_anchor=(0.9, -0.15, 0, 0))
ax1[0][1].legend(bbox_to_anchor=(0.4, -1.15, 0, 0))
ax1[1][1].legend(bbox_to_anchor=(0.9, -0.15, 0, 0))

ax1[1][0].set_ylim(-10, 20)
ax1[1][1].set_ylim(-10, 20)
fig.tight_layout()
fig.savefig("ablation.eps", format="eps", dpi=1200, bbox_inches="tight", transparent=True)
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %% [markdown]
# ### Test

# %%
## F1 for train and val                                                                Loss for train and val

fig = plt.figure(figsize=(16, 10))
gs = fig.add_gridspec(2, 2, hspace=0, wspace=0)
ax1 = gs.subplots(sharex='col', sharey='row')

fig.suptitle(f'Train and Validation - F1 Score and Loss Plots', fontsize=16)

epochs = [i for i in range(int(num_epochs))]

hand = []
lab = []


#plot = plot_names[i]
#ax1[i].set_title(f'{plot}')
for j in range(5):

    ax1[0][0].plot(epochs, metric_params['f1_score'][f'f1score_train_LR{j+1}'],
                    label = f'LR = {l_rates[j]}-F1 Score (Train)', 
                    color = colors_f1_score[f'f1score_train_LR{j+1}']
                    )
    ax1[0][0].set_xlabel('Loss Plot')
    ax1[0][0].set_ylabel('F1 Score')
    ax1[0][0].set_title("Training")
    #ax1[0][0].legend(bbox_to_anchor=(0.5, -1.05, 0.40, 0.94), loc='best')

    ax1[0][1].plot(epochs, metric_params['f1_score'][f'f1score_val_LR{j+1}'],
                    label = f'LR = {l_rates[j]}-F1 Score (Val)', 
                    color = colors_f1_score[f'f1score_val_LR{j+1}']
                    )
    ax1[0][1].set_title("Validation")
    ax1[0][1].legend(bbox_to_anchor=(0.5, -1.05, 0.40, 0.94))

#ax1[0][0].legend(bbox_to_anchor=(1, -1.05, 0.40, 0.94))

for j in range(5):
    ax1[1][0].plot(epochs, np.log(metric_params['loss'][f'loss_train_LR{j+1}']),
                    label = f'LR = {l_rates[j]}-Loss (Train)', 
                    color = colors_loss[f'loss_train_LR{j+1}']
                    )
    ax1[1][0].set_ylabel('Loss (Log Scale)')
    ax1[1][0].set_xlabel('Epochs')
    ax1[1][0].legend(bbox_to_anchor=(0.5, -1.05, 0.40, 0.94))

    ax1[1][1].plot(epochs, np.log(metric_params['loss'][f'loss_val_LR{j+1}']),
                    label = f'LR = {l_rates[j]}-Loss (Val)', 
                    color = colors_loss[f'loss_val_LR{j+1}']
                    )
    ax1[1][1].set_xlabel('Epochs')
    #ax1[1][1].legend(bbox_to_anchor=(0.5, -1.05, 0.40, 0.94))


    ax1[1][1].legend(bbox_to_anchor=(0, -1.05, 0.40, 0.94))
        
        # handles_ax00, labels_ax00 = ax1[0][0].get_legend_handles_labels()
        # hand.append(handles_ax00)
        # lab.append(labels_ax00)
        
    # for k in range(2):
    #     handles, labels = ax1[i][k].get_legend_handles_labels()
    #     hand.append(handles)
    #     lab.append(labels)
        

#handles_labels = [ax.get_legend_handles_labels() for ax in fig.axes]
# handles, labels = [sum(handles_and_labels, []) for handles_and_labels in zip(*lines_labels)]
#fig.legend(hand, lab, bbox_to_anchor=(0.5, -1.05, 0.40, 0.94))



ax1[1][0].set_ylim(-10, 10)
ax1[1][1].set_ylim(-10, 10)
# Out:
# (-10.0, 10.0)

# %%
## F1 for train and val                                                                Loss for train and val

fig = plt.figure(figsize=(16, 5))
gs = fig.add_gridspec(1, 2, hspace=0, wspace=0)
ax1 = gs.subplots(sharex='col', sharey='row')

ax2 = []
fig.suptitle(f'F1 score and Loss for Train and Validation', fontsize=16)

epochs = [i for i in range(int(num_epochs))]

for i, plot_type in enumerate(metric_params.keys()):
    plot = plot_names[i]
    ax1[i].set_title(f'{plot}')

    color = 'black'

    for metric in metric_params[plot_type].keys():
        if "val" in metric:
            try:
                ax1[i].plot(epochs, 
                        list(metric_params[plot_type][metric].items())[0][1],
                        # label=f'{dataset_names[data]} - Validation Accuracy', 
                        # color= colors_acc[metric]
                        )
            except:
                ax1[i].plot(epochs, 
                        metric_params[plot_type][metric],
                        # label=f'{dataset_names[data]} - Validation Accuracy', 
                        # color= colors_acc[metric]
                        )
        else:
            try:
                ax1[i].plot(epochs, 
                        list(metric_params[plot_type][metric].items())[0][1],
                        # label=f'{dataset_names[data]} - Validation Accuracy', 
                        # color= colors_acc[metric]
                            linestyle='--'
                        )
            except:
                ax1[i].plot(epochs, 
                        metric_params[plot_type][metric],
                        # label=f'{dataset_names[data]} - Validation Accuracy', 
                        # color= colors_acc[metric]
                            linestyle='--'
                        )
