# %%
## TODO: 
## 1. Get mean and std of dataset - done
## 2. Write a script to plot loss + accuracy graph
## 3. Get FLOPs - done
## 4. Get num layers - done
## ----------------------------------------------------
## 1. Implement differentiable F1 loss function
## 2. Add class weights
## 3. Implement transfer learning part - done
## 4. Implement T-SNE
## 5. Implement gradcam
## 6. Ablation study
##

# %%
import sys
sys.path.append('../../src/')

# %%
# %load_ext autoreload
# %autoreload 2

from train import train_model
from model import initialize_model
from utils import set_requires_grad, save_model
from data import load_data
from plotting import plot_data_loader
from eval import eval_model

# %%
import os
import copy
import time
import random
import pickle

import numpy as np
import pandas as pd
from PIL import Image
from pathlib import Path
from tqdm import tqdm

from sklearn.metrics import f1_score, confusion_matrix
from numpy.random import shuffle
import matplotlib.pyplot as plt

import torch
import torchvision
from torchvision.io import read_image
import torchvision.transforms as T
import torch.nn as nn
import torch.optim as optim
from torchvision import datasets, models, transforms
import torch.autograd.profiler as tprofiler
import torch.utils.data as td

plt.rcParams["savefig.bbox"] = 'tight'

# %%
seed = 42

random.seed(seed)

# pytorch RNGs
torch.manual_seed(seed)
torch.backends.cudnn.deterministic = True
if torch.cuda.is_available(): torch.cuda.manual_seed_all(seed)

# numpy RNG
np.random.seed(seed)

# %%
data_dir = "../../data"
images_dir = "../../data/covid_pneumonia"

# %%
# Get best num_workers
# for i in range(97):
#     start = time.time()
#     data_loader = load_data(images_dir,
#                                                                    batch_size = 96, 
#                                                                    input_size = 299, 
#                                                                    norm_arr = ([0.485, 0.456, 0.406], [0.229, 0.224, 0.225]),
#                                                                    num_workers = i)
#     iter(data_loader['train']).next()[0].shape
#     print(f"{i}: {time.time()-start}")

# %%
# Models options: resnet50, resnet34, inceptionv3, vgg16, mobile_net_v3_large, efficient_net_b1, efficient_net_b0.
model_name = "resnet34"

# Number of classes.
num_classes = 3

# Batch Size.
batch_size = 32

# Epochs to train for.
num_epochs = 100

# Number of workers for data loader.
num_workers = 12

# Imagenet norm array passed as default value.
norm_arr=([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
# Chest x-ray8 training dataset metrics 
norm_arr=([0.4951, 0.4951, 0.4951], [0.2896, 0.2896, 0.2896])
# Covid Pneumonia dataset metrics
norm_arr = ([0.5159, 0.5159, 0.5159], [0.2554, 0.2554, 0.2554])

# Feature extract flag: False - Tune the whole model,
#                       True - Update only the reshaped layer parameters.
feature_extract = False

# Use pretrained flag: None - Use random weights
#                      String - Use pretrained weights given by String
use_pretrained = None

# Initialize the model for this run.
model_pyt, input_size = initialize_model(model_name, num_classes, feature_extract, use_pretrained=use_pretrained)

# lr start and end points for training.
lr_start = 0.01
lr_end = 0.001

# How many epochs to restart.
iter_restart = 10

# Multiplication factor after restart.
mul_restart = 1

# Print the model we just instantiated
#print(model_ft)

# %%
data_loaders = load_data(images_dir,
                         batch_size = batch_size, 
                         input_size = input_size, 
                         norm_arr = norm_arr,
                         num_workers = num_workers)

# %% [markdown]
# plot_data_loader(data_loader['train'], (2,2))

# %% [markdown]
# plot_data_loader(data_loader['test'], (2,2))

# %% [markdown]
# plot_data_loader(data_loader['val'], (2,2))

# %%
# Check if GPU is available.
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(device)

# Send model to GPU
model_pyt = model_pyt.to(device)

# Find parameters to be updated in this run.
# parameters with requires_grad = True.
params_to_update = model_pyt.parameters()
print("Params to learn:")
if feature_extract:
    params_to_update = []
    for name,param in model_pyt.named_parameters():
        if param.requires_grad == True:
            params_to_update.append(param)
            print("\t",name)
else:
    for name,param in model_pyt.named_parameters():
        if param.requires_grad == True:
            print("\t",name)
# Out:
# cuda:0
# Params to learn:
# 	 conv1.weight
# 	 bn1.weight
# 	 bn1.bias
# 	 layer1.0.conv1.weight
# 	 layer1.0.bn1.weight
# 	 layer1.0.bn1.bias
# 	 layer1.0.conv2.weight
# 	 layer1.0.bn2.weight
# 	 layer1.0.bn2.bias
# 	 layer1.1.conv1.weight
# 	 layer1.1.bn1.weight
# 	 layer1.1.bn1.bias
# 	 layer1.1.conv2.weight
# 	 layer1.1.bn2.weight
# 	 layer1.1.bn2.bias
# 	 layer1.2.conv1.weight
# 	 layer1.2.bn1.weight
# 	 layer1.2.bn1.bias
# 	 layer1.2.conv2.weight
# 	 layer1.2.bn2.weight
# 	 layer1.2.bn2.bias
# 	 layer2.0.conv1.weight
# 	 layer2.0.bn1.weight
# 	 layer2.0.bn1.bias
# 	 layer2.0.conv2.weight
# 	 layer2.0.bn2.weight
# 	 layer2.0.bn2.bias
# 	 layer2.0.downsample.0.weight
# 	 layer2.0.downsample.1.weight
# 	 layer2.0.downsample.1.bias
# 	 layer2.1.conv1.weight
# 	 layer2.1.bn1.weight
# 	 layer2.1.bn1.bias
# 	 layer2.1.conv2.weight
# 	 layer2.1.bn2.weight
# 	 layer2.1.bn2.bias
# 	 layer2.2.conv1.weight
# 	 layer2.2.bn1.weight
# 	 layer2.2.bn1.bias
# 	 layer2.2.conv2.weight
# 	 layer2.2.bn2.weight
# 	 layer2.2.bn2.bias
# 	 layer2.3.conv1.weight
# 	 layer2.3.bn1.weight
# 	 layer2.3.bn1.bias
# 	 layer2.3.conv2.weight
# 	 layer2.3.bn2.weight
# 	 layer2.3.bn2.bias
# 	 layer3.0.conv1.weight
# 	 layer3.0.bn1.weight
# 	 layer3.0.bn1.bias
# 	 layer3.0.conv2.weight
# 	 layer3.0.bn2.weight
# 	 layer3.0.bn2.bias
# 	 layer3.0.downsample.0.weight
# 	 layer3.0.downsample.1.weight
# 	 layer3.0.downsample.1.bias
# 	 layer3.1.conv1.weight
# 	 layer3.1.bn1.weight
# 	 layer3.1.bn1.bias
# 	 layer3.1.conv2.weight
# 	 layer3.1.bn2.weight
# 	 layer3.1.bn2.bias
# 	 layer3.2.conv1.weight
# 	 layer3.2.bn1.weight
# 	 layer3.2.bn1.bias
# 	 layer3.2.conv2.weight
# 	 layer3.2.bn2.weight
# 	 layer3.2.bn2.bias
# 	 layer3.3.conv1.weight
# 	 layer3.3.bn1.weight
# 	 layer3.3.bn1.bias
# 	 layer3.3.conv2.weight
# 	 layer3.3.bn2.weight
# 	 layer3.3.bn2.bias
# 	 layer3.4.conv1.weight
# 	 layer3.4.bn1.weight
# 	 layer3.4.bn1.bias
# 	 layer3.4.conv2.weight
# 	 layer3.4.bn2.weight
# 	 layer3.4.bn2.bias
# 	 layer3.5.conv1.weight
# 	 layer3.5.bn1.weight
# 	 layer3.5.bn1.bias
# 	 layer3.5.conv2.weight
# 	 layer3.5.bn2.weight
# 	 layer3.5.bn2.bias
# 	 layer4.0.conv1.weight
# 	 layer4.0.bn1.weight
# 	 layer4.0.bn1.bias
# 	 layer4.0.conv2.weight
# 	 layer4.0.bn2.weight
# 	 layer4.0.bn2.bias
# 	 layer4.0.downsample.0.weight
# 	 layer4.0.downsample.1.weight
# 	 layer4.0.downsample.1.bias
# 	 layer4.1.conv1.weight
# 	 layer4.1.bn1.weight
# 	 layer4.1.bn1.bias
# 	 layer4.1.conv2.weight
# 	 layer4.1.bn2.weight
# 	 layer4.1.bn2.bias
# 	 layer4.2.conv1.weight
# 	 layer4.2.bn1.weight
# 	 layer4.2.bn1.bias
# 	 layer4.2.conv2.weight
# 	 layer4.2.bn2.weight
# 	 layer4.2.bn2.bias
# 	 fc.weight
# 	 fc.bias

# %%
# 17 min 1 epoch - 128 batch size - inception
# Efficientnet b0 - batch 96 - epoch 50 - num_workers 2 - flip, auto cont, sharp -

# %%
# Observe that all parameters are being optimized
optimizer = optim.Adam(params_to_update, lr=lr_start)

# Learning rate scheduler.
scheduler = optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=num_epochs, eta_min=lr_end, last_epoch=-1)

# Setup the loss fxn
criterion = nn.CrossEntropyLoss()

# Train and evaluate
model_pyt, prof, val_history, train_history = train_model(device, model_pyt, data_loaders, 
                                                            optimizer, scheduler,
                                                            criterion, 
                                                            num_epochs=num_epochs,
                                                            num_classes=num_classes,
                                                            is_inception=(model_name=="inceptionv3"),
                                                            profiler=False)
# Out:
# Epoch 1/100
# ----------
# Epoch [1/100], Step [100/332], Loss: 0.6370, Accuracy: 23.00%
# Epoch [1/100], Step [200/332], Loss: 0.4779, Accuracy: 24.00%
# Epoch [1/100], Step [300/332], Loss: 0.4050, Accuracy: 25.00%
# train Loss: 0.6219 Acc: 0.7362
# val Loss: 0.8937 Acc: 0.6890
#
# Epoch 2/100
# ----------
# Epoch [2/100], Step [100/332], Loss: 0.6112, Accuracy: 23.00%
# Epoch [2/100], Step [200/332], Loss: 0.3953, Accuracy: 26.00%
# Epoch [2/100], Step [300/332], Loss: 0.4589, Accuracy: 24.00%
# train Loss: 0.4682 Acc: 0.8023
# val Loss: 0.5336 Acc: 0.7800
#
# Epoch 3/100
# ----------
# Epoch [3/100], Step [100/332], Loss: 0.4659, Accuracy: 24.00%
# Epoch [3/100], Step [200/332], Loss: 0.2616, Accuracy: 28.00%
# Epoch [3/100], Step [300/332], Loss: 0.5460, Accuracy: 24.00%
100], Step [300/332], Loss: 0.0000, Accuracy: 32.00%
# train Loss: 0.0062 Acc: 0.9982
# val Loss: 0.2143 Acc: 0.9608
#
# Epoch 50/100
# ----------
# Epoch [50/100], Step [100/332], Loss: 0.0022, Accuracy: 32.00%
# Epoch [50/100], Step [200/332], Loss: 0.0002, Accuracy: 32.00%
# Epoch [50/100], Step [300/332], Loss: 0.0003, Accuracy: 32.00%
# train Loss: 0.0082 Acc: 0.9966
# val Loss: 0.2531 Acc: 0.9538
#
# Epoch 51/100
# ----------
# Epoch [51/100], Step [100/332], Loss: 0.0061, Accuracy: 32.00%
# Epoch [51/100], Step [200/332], Loss: 0.0006, Accuracy: 32.00%
# Epoch [51/100], Step [300/332], Loss: 0.0007, Accuracy: 32.00%
# train Loss: 0.0149 Acc: 0.9952
# val Loss: 0.1707 Acc: 0.9595
#
# Epoch 52/100
# ----------
# Epoch [52/100], Step [100/332], Loss: 0.0013, Accuracy: 32.00%
# Epoch [52/100], Step [200/332], Loss: 0.0003, Accuracy: 32.00%
# Epoch [52/100], Step [300/332], Loss: 0.0003, Accuracy: 32.00%
# train Loss: 0.0055 Acc: 0.9984
# val Loss: 0.1996 Acc: 0.9564
#
# Epoch 53/100
# ----------
# Epoch [53/100], Step [100/332], Loss: 0.0080, Accuracy: 32.00%
# Epoch [53/100], Step [200/332], Loss: 0.0012, Accuracy: 32.00%
# Epoch [53/100], Step [300/332], Loss: 0.0010, Accuracy: 32.00%
# train Loss: 0.0054 Acc: 0.9977
# val Loss: 0.2347 Acc: 0.9534
#
# Epoch 54/100
# ----------
# Epoch [54/100], Step [100/332], Loss: 0.0000, Accuracy: 32.00%
# Epoch [54/100], Step [200/332], Loss: 0.0005, Accuracy: 32.00%
# Epoch [54/100], Step [300/332], Loss: 0.0000, Accuracy: 32.00%
# train Loss: 0.0060 Acc: 0.9977
# val Loss: 0.1695 Acc: 0.9652
#
# Epoch 55/100
# ----------
# Epoch [55/100], Step [100/332], Loss: 0.0001, Accuracy: 32.00%
# Epoch [55/100], Step [200/332], Loss: 0.0000, Accuracy: 32.00%
# Epoch [55/100], Step [300/332], Loss: 0.0025, Accuracy: 32.00%
# train Loss: 0.0040 Acc: 0.9983
# val Loss: 0.2736 Acc: 0.9525
#
# Epoch 56/100
# ----------
# Epoch [56/100], Step [100/332], Loss: 0.0018, Accuracy: 32.00%
# Epoch [56/100], Step [200/332], Loss: 0.0004, Accuracy: 32.00%
# Epoch [56/100], Step [300/332], Loss: 0.0000, Accuracy: 32.00%
# train Loss: 0.0058 Acc: 0.9986
# val Loss: 0.2272 Acc: 0.9586
#
# Epoch 57/100
# ----------
# Epoch [57/100], Step [100/332], Loss: 0.0001, Accuracy: 32.00%
# Epoch [57/100], Step [200/332], Loss: 0.0006, Accuracy: 32.00%
# Epoch [57/100], Step [300/332], Loss: 0.0013, Accuracy: 32.00%
# train Loss: 0.0139 Acc: 0.9959
# val Loss: 0.1673 Acc: 0.9617
#
# Epoch 58/100
# ----------
# Epoch [58/100], Step [100/332], Loss: 0.0003, Accuracy: 32.00%
# Epoch [58/100], Step [200/332], Loss: 0.0000, Accuracy: 32.00%
# Epoch [58/100], Step [300/332], Loss: 0.0167, Accuracy: 32.00%
# train Loss: 0.0028 Acc: 0.9993
# val Loss: 0.1480 Acc: 0.9674
#
# Epoch 59/100
# ----------
# Epoch [59/100], Step [100/332], Loss: 0.0026, Accuracy: 32.00%
# Epoch [59/100], Step [200/332], Loss: 0.0001, Accuracy: 32.00%
# Epoch [59/100], Step [300/332], Loss: 0.0012, Accuracy: 32.00%
# train Loss: 0.0018 Acc: 0.9994
# val Loss: 0.1658 Acc: 0.9679
#
# Epoch 60/100
# ----------
# Epoch [60/100], Step [100/332], Loss: 0.0002, Accuracy: 32.00%
# Epoch [60/100], Step [200/332], Loss: 0.0000, Accuracy: 32.00%
# Epoch [60/100], Step [300/332], Loss: 0.0003, Accuracy: 32.00%
# train Loss: 0.0016 Acc: 0.9994
# val Loss: 0.2888 Acc: 0.9569
#
# Epoch 61/100
# ----------
# Epoch [61/100], Step [100/332], Loss: 0.0003, Accuracy: 32.00%
# Epoch [61/100], Step [200/332], Loss: 0.0000, Accuracy: 32.00%
# Epoch [61/100], Step [300/332], Loss: 0.0000, Accuracy: 32.00%
# train Loss: 0.0020 Acc: 0.9992
# val Loss: 0.1705 Acc: 0.9692
#
# Epoch 62/100
# ----------
# Epoch [62/100], Step [100/332], Loss: 0.0001, Accuracy: 32.00%
# Epoch [62/100], Step [200/332], Loss: 0.0017, Accuracy: 32.00%
# Epoch [62/100], Step [300/332], Loss: 0.0000, Accuracy: 32.00%
# train Loss: 0.0040 Acc: 0.9988
# val Loss: 0.2080 Acc: 0.9622
#
# Epoch 63/100
# ----------
# Epoch [63/100], Step [100/332], Loss: 0.0000, Accuracy: 32.00%
# Epoch [63/100], Step [200/332], Loss: 0.0002, Accuracy: 32.00%
# Epoch [63/100], Step [300/332], Loss: 0.0002, Accuracy: 32.00%
# train Loss: 0.0081 Acc: 0.9974
# val Loss: 0.1828 Acc: 0.9613
#
# Epoch 64/100
# ----------
# Epoch [64/100], Step [100/332], Loss: 0.0000, Accuracy: 32.00%
# Epoch [64/100], Step [200/332], Loss: 0.0098, Accuracy: 32.00%
# Epoch [64/100], Step [300/332], Loss: 0.0001, Accuracy: 32.00%
# train Loss: 0.0040 Acc: 0.9992
# val Loss: 0.1686 Acc: 0.9705
#
# Epoch 65/100
# ----------
# Epoch [65/100], Step [100/332], Loss: 0.0092, Accuracy: 32.00%
# Epoch [65/100], Step [200/332], Loss: 0.0002, Accuracy: 32.00%
# Epoch [65/100], Step [300/332], Loss: 0.0001, Accuracy: 32.00%
# train Loss: 0.0032 Acc: 0.9989
# val Loss: 0.1702 Acc: 0.9692
#
# Epoch 66/100
# ----------
# Epoch [66/100], Step [100/332], Loss: 0.0079, Accuracy: 32.00%
# Epoch [66/100], Step [200/332], Loss: 0.0000, Accuracy: 32.00%
# Epoch [66/100], Step [300/332], Loss: 0.0000, Accuracy: 32.00%
# train Loss: 0.0011 Acc: 0.9997
# val Loss: 0.1577 Acc: 0.9710
#
# Epoch 67/100
# ----------
# Epoch [67/100], Step [100/332], Loss: 0.0001, Accuracy: 32.00%
# Epoch [67/100], Step [200/332], Loss: 0.0003, Accuracy: 32.00%
# Epoch [67/100], Step [300/332], Loss: 0.0001, Accuracy: 32.00%
# train Loss: 0.0009 Acc: 0.9998
# val Loss: 0.1779 Acc: 0.9696
#
# Epoch 68/100
# ----------
# Epoch [68/100], Step [100/332], Loss: 0.0000, Accuracy: 32.00%
# Epoch [68/100], Step [200/332], Loss: 0.0018, Accuracy: 32.00%
# Epoch [68/100], Step [300/332], Loss: 0.0002, Accuracy: 32.00%
# train Loss: 0.0036 Acc: 0.9986
# val Loss: 0.1778 Acc: 0.9705
#
# Epoch 69/100
# ----------
# Epoch [69/100], Step [100/332], Loss: 0.0004, Accuracy: 32.00%
# Epoch [69/100], Step [200/332], Loss: 0.0000, Accuracy: 32.00%
# Epoch [69/100], Step [300/332], Loss: 0.0000, Accuracy: 32.00%
# train Loss: 0.0015 Acc: 0.9994
# val Loss: 0.1793 Acc: 0.9670
#
# Epoch 70/100
# ----------
# Epoch [70/100], Step [100/332], Loss: 0.0015, Accuracy: 32.00%
# Epoch [70/100], Step [200/332], Loss: 0.0001, Accuracy: 32.00%
# Epoch [70/100], Step [300/332], Loss: 0.0001, Accuracy: 32.00%
# train Loss: 0.0019 Acc: 0.9996
# val Loss: 0.1658 Acc: 0.9714
#
# Epoch 71/100
# ----------
# Epoch [71/100], Step [100/332], Loss: 0.0000, Accuracy: 32.00%
# Epoch [71/100], Step [200/332], Loss: 0.0000, Accuracy: 32.00%
# Epoch [71/100], Step [300/332], Loss: 0.0000, Accuracy: 32.00%
# train Loss: 0.0003 Acc: 1.0000
# val Loss: 0.1651 Acc: 0.9718
#
# Epoch 72/100
# ----------
# Epoch [72/100], Step [100/332], Loss: 0.0001, Accuracy: 32.00%
# Epoch [72/100], Step [200/332], Loss: 0.0001, Accuracy: 32.00%
# Epoch [72/100], Step [300/332], Loss: 0.0002, Accuracy: 32.00%
# train Loss: 0.0035 Acc: 0.9988
# val Loss: 0.2122 Acc: 0.9696
#
# Epoch 73/100
# ----------
# Epoch [73/100], Step [100/332], Loss: 0.0000, Accuracy: 32.00%
# Epoch [73/100], Step [200/332], Loss: 0.0000, Accuracy: 32.00%
# Epoch [73/100], Step [300/332], Loss: 0.0001, Accuracy: 32.00%
# train Loss: 0.0039 Acc: 0.9986
# val Loss: 0.1737 Acc: 0.9661
#
# Epoch 74/100
# ----------
# Epoch [74/100], Step [100/332], Loss: 0.0002, Accuracy: 32.00%
# Epoch [74/100], Step [200/332], Loss: 0.0000, Accuracy: 32.00%
# Epoch [74/100], Step [300/332], Loss: 0.0000, Accuracy: 32.00%
# train Loss: 0.0003 Acc: 1.0000
# val Loss: 0.1840 Acc: 0.9679
#
# Epoch 75/100
# ----------
# Epoch [75/100], Step [100/332], Loss: 0.0014, Accuracy: 32.00%
# Epoch [75/100], Step [200/332], Loss: 0.0000, Accuracy: 32.00%
# Epoch [75/100], Step [300/332], Loss: 0.0000, Accuracy: 32.00%
# train Loss: 0.0003 Acc: 0.9999
# val Loss: 0.1818 Acc: 0.9657
#
# Epoch 76/100
# ----------
# Epoch [76/100], Step [100/332], Loss: 0.0000, Accuracy: 32.00%
# Epoch [76/100], Step [200/332], Loss: 0.0000, Accuracy: 32.00%
# Epoch [76/100], Step [300/332], Loss: 0.0000, Accuracy: 32.00%
# train Loss: 0.0009 Acc: 0.9997
# val Loss: 0.2180 Acc: 0.9635
#
# Epoch 77/100
# ----------
# Epoch [77/100], Step [100/332], Loss: 0.0000, Accuracy: 32.00%
# Epoch [77/100], Step [200/332], Loss: 0.0000, Accuracy: 32.00%
# Epoch [77/100], Step [300/332], Loss: 0.0001, Accuracy: 32.00%
# train Loss: 0.0003 Acc: 0.9999
# val Loss: 0.2033 Acc: 0.9652
#
# Epoch 78/100
# ----------
# Epoch [78/100], Step [100/332], Loss: 0.0008, Accuracy: 32.00%
# Epoch [78/100], Step [200/332], Loss: 0.0000, Accuracy: 32.00%
# Epoch [78/100], Step [300/332], Loss: 0.0000, Accuracy: 32.00%
# train Loss: 0.0003 Acc: 1.0000
# val Loss: 0.2048 Acc: 0.9661
#
# Epoch 79/100
# ----------
# Epoch [79/100], Step [100/332], Loss: 0.0000, Accuracy: 32.00%
# Epoch [79/100], Step [200/332], Loss: 0.0000, Accuracy: 32.00%
# Epoch [79/100], Step [300/332], Loss: 0.0000, Accuracy: 32.00%
# train Loss: 0.0005 Acc: 0.9999
# val Loss: 0.2095 Acc: 0.9670
#
# Epoch 80/100
# ----------
# Epoch [80/100], Step [100/332], Loss: 0.0000, Accuracy: 32.00%
# Epoch [80/100], Step [200/332], Loss: 0.0001, Accuracy: 32.00%
# Epoch [80/100], Step [300/332], Loss: 0.0000, Accuracy: 32.00%
# train Loss: 0.0008 Acc: 0.9996
# val Loss: 0.2305 Acc: 0.9635
#
# Epoch 81/100
# ----------
# Epoch [81/100], Step [100/332], Loss: 0.0000, Accuracy: 32.00%
# Epoch [81/100], Step [200/332], Loss: 0.0086, Accuracy: 32.00%
# Epoch [81/100], Step [300/332], Loss: 0.0000, Accuracy: 32.00%
# train Loss: 0.0004 Acc: 1.0000
# val Loss: 0.1930 Acc: 0.9692
#
# Epoch 82/100
# ----------
# Epoch [82/100], Step [100/332], Loss: 0.0000, Accuracy: 32.00%
# Epoch [82/100], Step [200/332], Loss: 0.0000, Accuracy: 32.00%
# Epoch [82/100], Step [300/332], Loss: 0.0000, Accuracy: 32.00%
# train Loss: 0.0017 Acc: 0.9993
# val Loss: 0.3360 Acc: 0.9534
#
# Epoch 83/100
# ----------
# Epoch [83/100], Step [100/332], Loss: 0.0002, Accuracy: 32.00%
# Epoch [83/100], Step [200/332], Loss: 0.0001, Accuracy: 32.00%
# Epoch [83/100], Step [300/332], Loss: 0.0000, Accuracy: 32.00%
# train Loss: 0.0028 Acc: 0.9992
# val Loss: 0.2543 Acc: 0.9630
#
# Epoch 84/100
# ----------
# Epoch [84/100], Step [100/332], Loss: 0.0003, Accuracy: 32.00%
# Epoch [84/100], Step [200/332], Loss: 0.0014, Accuracy: 32.00%
# Epoch [84/100], Step [300/332], Loss: 0.0001, Accuracy: 32.00%
# train Loss: 0.0003 Acc: 0.9999
# val Loss: 0.2508 Acc: 0.9626
#
# Epoch 85/100
# ----------
# Epoch [85/100], Step [100/332], Loss: 0.0000, Accuracy: 32.00%
# Epoch [85/100], Step [200/332], Loss: 0.0000, Accuracy: 32.00%
# Epoch [85/100], Step [300/332], Loss: 0.0000, Accuracy: 32.00%
# train Loss: 0.0001 Acc: 1.0000
# val Loss: 0.2227 Acc: 0.9661
#
# Epoch 86/100
# ----------
# Epoch [86/100], Step [100/332], Loss: 0.0000, Accuracy: 32.00%
# Epoch [86/100], Step [200/332], Loss: 0.0000, Accuracy: 32.00%
# Epoch [86/100], Step [300/332], Loss: 0.0001, Accuracy: 32.00%
# train Loss: 0.0001 Acc: 1.0000
# val Loss: 0.2273 Acc: 0.9657
#
# Epoch 87/100
# ----------
# Epoch [87/100], Step [100/332], Loss: 0.0000, Accuracy: 32.00%
# Epoch [87/100], Step [200/332], Loss: 0.0000, Accuracy: 32.00%
# Epoch [87/100], Step [300/332], Loss: 0.0001, Accuracy: 32.00%
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.2346 Acc: 0.9657
#
# Epoch 88/100
# ----------
# Epoch [88/100], Step [100/332], Loss: 0.0000, Accuracy: 32.00%
# Epoch [88/100], Step [200/332], Loss: 0.0000, Accuracy: 32.00%
# Epoch [88/100], Step [300/332], Loss: 0.0000, Accuracy: 32.00%
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.2236 Acc: 0.9670
#
# Epoch 89/100
# ----------
# Epoch [89/100], Step [100/332], Loss: 0.0000, Accuracy: 32.00%
# Epoch [89/100], Step [200/332], Loss: 0.0000, Accuracy: 32.00%
# Epoch [89/100], Step [300/332], Loss: 0.0000, Accuracy: 32.00%
# train Loss: 0.0006 Acc: 0.9996
# val Loss: 0.2506 Acc: 0.9648
#
# Epoch 90/100
# ----------
# Epoch [90/100], Step [100/332], Loss: 0.0000, Accuracy: 32.00%
# Epoch [90/100], Step [200/332], Loss: 0.0000, Accuracy: 32.00%
# Epoch [90/100], Step [300/332], Loss: 0.0000, Accuracy: 32.00%
# train Loss: 0.0002 Acc: 0.9998
# val Loss: 0.2503 Acc: 0.9635
#
# Epoch 91/100
# ----------
# Epoch [91/100], Step [100/332], Loss: 0.0000, Accuracy: 32.00%
# Epoch [91/100], Step [200/332], Loss: 0.0000, Accuracy: 32.00%
# Epoch [91/100], Step [300/332], Loss: 0.0002, Accuracy: 32.00%
# train Loss: 0.0003 Acc: 0.9999
# val Loss: 0.2370 Acc: 0.9661
#
# Epoch 92/100
# ----------
# Epoch [92/100], Step [100/332], Loss: 0.0000, Accuracy: 32.00%
# Epoch [92/100], Step [200/332], Loss: 0.0000, Accuracy: 32.00%
# Epoch [92/100], Step [300/332], Loss: 0.0000, Accuracy: 32.00%
# train Loss: 0.0014 Acc: 0.9996
# val Loss: 0.2275 Acc: 0.9679
#
# Epoch 93/100
# ----------
# Epoch [93/100], Step [100/332], Loss: 0.0000, Accuracy: 32.00%
# Epoch [93/100], Step [200/332], Loss: 0.0000, Accuracy: 32.00%
# Epoch [93/100], Step [300/332], Loss: 0.0014, Accuracy: 32.00%
# train Loss: 0.0005 Acc: 0.9998
# val Loss: 0.2299 Acc: 0.9639
#
# Epoch 94/100
# ----------
# Epoch [94/100], Step [100/332], Loss: 0.0000, Accuracy: 32.00%
# Epoch [94/100], Step [200/332], Loss: 0.0001, Accuracy: 32.00%
# Epoch [94/100], Step [300/332], Loss: 0.0000, Accuracy: 32.00%
# train Loss: 0.0002 Acc: 0.9999
# val Loss: 0.3104 Acc: 0.9551
#
# Epoch 95/100
# ----------
# Epoch [95/100], Step [100/332], Loss: 0.0000, Accuracy: 32.00%
# Epoch [95/100], Step [200/332], Loss: 0.0000, Accuracy: 32.00%
# Epoch [95/100], Step [300/332], Loss: 0.0000, Accuracy: 32.00%
# train Loss: 0.0011 Acc: 0.9998
# val Loss: 0.2487 Acc: 0.9622
#
# Epoch 96/100
# ----------
# Epoch [96/100], Step [100/332], Loss: 0.0000, Accuracy: 32.00%
# Epoch [96/100], Step [200/332], Loss: 0.0000, Accuracy: 32.00%
# Epoch [96/100], Step [300/332], Loss: 0.0000, Accuracy: 32.00%
# train Loss: 0.0001 Acc: 1.0000
# val Loss: 0.2278 Acc: 0.9674
#
# Epoch 97/100
# ----------
# Epoch [97/100], Step [100/332], Loss: 0.0000, Accuracy: 32.00%
# Epoch [97/100], Step [200/332], Loss: 0.0000, Accuracy: 32.00%
# Epoch [97/100], Step [300/332], Loss: 0.0000, Accuracy: 32.00%
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.2224 Acc: 0.9683
#
# Epoch 98/100
# ----------
# Epoch [98/100], Step [100/332], Loss: 0.0000, Accuracy: 32.00%
# Epoch [98/100], Step [200/332], Loss: 0.0000, Accuracy: 32.00%
# Epoch [98/100], Step [300/332], Loss: 0.0000, Accuracy: 32.00%
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.2230 Acc: 0.9674
#
# Epoch 99/100
# ----------
# Epoch [99/100], Step [100/332], Loss: 0.0000, Accuracy: 32.00%
# Epoch [99/100], Step [200/332], Loss: 0.0000, Accuracy: 32.00%
# Epoch [99/100], Step [300/332], Loss: 0.0000, Accuracy: 32.00%
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.2224 Acc: 0.9692
#
# Epoch 100/100
# ----------
# Epoch [100/100], Step [100/332], Loss: 0.0000, Accuracy: 32.00%
# Epoch [100/100], Step [200/332], Loss: 0.0000, Accuracy: 32.00%
# Epoch [100/100], Step [300/332], Loss: 0.0000, Accuracy: 32.00%
# train Loss: 0.0000 Acc: 1.0000
# val Loss: 0.2169 Acc: 0.9701
#
# Training complete in 112m 44s
# Best val Acc: 0.971843

# %%
dataset_name = 'covid_pneumonia'

# %%
save_model(model_pyt, '../../models/', 
           f'{model_name}_{dataset_name}_{num_epochs}_{batch_size}_{lr_start}_{lr_end}_model_weights.pth')
# Out:
# True

# %%
eval_metrics = eval_model(device=device, model=model_pyt, test_loader=data_loaders['test'], is_inception=(model_name=="inceptionv3"))

# %%
for i, v in eval_metrics.items():
    print(f"{i}: {v}")
# Out:
# acc: 0.9714034315882095
# f1: 0.9637781799902942
# cm: [[ 520   20    2]
#  [  28 1492    9]
#  [   1    5  196]]
# outputs: [0 0 0 ... 2 2 2]
# targets: [0 0 0 ... 2 2 2]

# %%
with open(f'../../models/val_history_{model_name}_{dataset_name}_{num_epochs}_{batch_size}_{lr_start}_{lr_end}_.pickle', 'wb') as handle:
    pickle.dump(val_history, handle, protocol=pickle.HIGHEST_PROTOCOL)
with open(f'../../models/train_history_{model_name}_{dataset_name}_{num_epochs}_{batch_size}_{lr_start}_{lr_end}_.pickle', 'wb') as handle:
    pickle.dump(train_history, handle, protocol=pickle.HIGHEST_PROTOCOL)
with open(f'../../models/eval_metrics_{model_name}_{dataset_name}_{num_epochs}_{batch_size}_{lr_start}_{lr_end}_.pickle', 'wb') as handle:
    pickle.dump(eval_metrics, handle, protocol=pickle.HIGHEST_PROTOCOL)

#with open('filename.pickle', 'rb') as handle:
#    b = pickle.load(handle)

# %%
#print(prof.key_averages(group_by_stack_n=5).table(sort_by='self_cpu_time_total', row_limit=50))

# %%
# Plot the training curves of validation accuracy vs. number
#  of training epochs for the transfer learning method and
#  the model trained from scratch
# vhist = []
# vhist = [h.cpu().numpy() for h in val_acc_history]
# thist = []
# thist = [h.cpu().numpy() for h in train_acc_history]

# plt.title("Accuracy vs. Number of Training Epochs")
# plt.xlabel("Training Epochs")
# plt.ylabel("Accuracy")
# #plt.plot(range(1,num_epochs+1),ohist,label="Pretrained")
# plt.plot(range(1,num_epochs+1),vhist,label="Validation")
# plt.plot(range(1,num_epochs+1),thist,label="Training")
# plt.ylim((0,1.))
# plt.xticks(np.arange(1, num_epochs+1, 1.0))
# plt.legend()
# plt.show()

# %%
# Plot the training curves of validation accuracy vs. number
#  of training epochs for the transfer learning method and
#  the model trained from scratch
# vhist = []
# vhist = [h for h in val_loss_history]
# thist = []
# thist = [h for h in train_loss_history]

# plt.title("Loss vs. Number of Training Epochs")
# plt.xlabel("Training Epochs")
# plt.ylabel("Loss")
# #plt.plot(range(1,num_epochs+1),ohist,label="Pretrained")
# plt.plot(range(1,num_epochs+1),vhist,label="Validation")
# plt.plot(range(1,num_epochs+1),thist,label="Training")
# plt.ylim((0,1.))
# plt.xticks(np.arange(1, num_epochs+1, 1.0))
# plt.legend()
# plt.show()
