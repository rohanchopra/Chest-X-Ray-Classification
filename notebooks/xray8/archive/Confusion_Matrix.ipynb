# %%
import torch
import torchvision.transforms as transforms
import torchvision.datasets as datasets
import torch.utils.data as td
import numpy as np
import matplotlib.pyplot as plt
import torch.nn as nn
import torch.nn.functional as F
from matplotlib import image
from matplotlib import pyplot
import time
from torchsummary import summary
import seaborn as sns

# %%
plt.figure(figsize=(12,8))
ax= plt.subplot()
df_cm = np.array([[ 171,   71,   79,    1,  372,    5,   36],
        [  76,  294,  172,    3,  175,    4,   52],
        [  88,  106,  590,    9,  942,   13,   56],
        [  12,   29,   62,   25,  221,   15,   48],
        [ 125,   81,  177,   13, 3191,    8,   72],
        [  15,   16,   80,    9,  343,   22,   32],
        [  24,   33,   79,    3,  195,    2,  151]])
vmin = np.min(df_cm)
vmax = np.max(df_cm)
off_diag_mask = np.eye(*df_cm.shape, dtype=bool)
labels = ['Atelectasis','Effusion','Infiltration','Mass','No Finding','Nodule','Pneumothorax']

sns.heatmap(df_cm, annot=True, fmt="g", mask=~off_diag_mask, cmap='Greens',vmin=vmin, vmax=vmax,ax=ax)
sns.heatmap(df_cm, annot=True, fmt="g", mask=off_diag_mask, cmap='gray_r',vmin=vmin, vmax=vmax,xticklabels=labels, yticklabels=labels)
ax.set_title('Confusion Matrix for Chest X-ray8 Dataset using Resnet');

# %%
plt.figure(figsize=(12,8))
ax= plt.subplot()
df_cm = np.array([[  79,   94,   81,    0,  450,    0,   31],
        [  37,  348,  157,    0,  185,    0,   49],
        [  30,  129,  582,    0,  992,    4,   67],
        [   8,   52,   59,    0,  252,    2,   39],
        [  51,  122,  145,    0, 3271,    4,   74],
        [   8,   28,   82,    0,  360,    3,   36],
        [   8,   66,   82,    0,  217,    0,  114]])
vmin = np.min(df_cm)
vmax = np.max(df_cm)
off_diag_mask = np.eye(*df_cm.shape, dtype=bool)
labels = ['Atelectasis','Effusion','Infiltration','Mass','No Finding','Nodule','Pneumothorax']

sns.heatmap(df_cm, annot=True, fmt="g", mask=~off_diag_mask, cmap='Greens',vmin=vmin, vmax=vmax,ax=ax, )
sns.heatmap(df_cm, annot=True, fmt="g", mask=off_diag_mask, cmap='gray_r',vmin=vmin, vmax=vmax,xticklabels=labels, yticklabels=labels)
ax.set_title('Confusion Matrix for Chest X-ray8 Dataset using MobileNet');

# %%
plt.figure(figsize=(12,8))
ax= plt.subplot()
df_cm = np.array([[ 199,  106,   64,    8,  338,    3,   17],
        [  66,  395,  133,    7,  155,    1,   19],
        [  89,  137,  559,   16,  957,   10,   36],
        [  30,   40,   54,   47,  221,    6,   14],
        [ 166,  122,  155,   26, 3148,    6,   44],
        [  18,   22,   76,   23,  344,   12,   22],
        [  41,   52,   80,    6,  217,    3,   88]])
vmin = np.min(df_cm)
vmax = np.max(df_cm)
off_diag_mask = np.eye(*df_cm.shape, dtype=bool)
labels = ['Atelectasis','Effusion','Infiltration','Mass','No Finding','Nodule','Pneumothorax']

sns.heatmap(df_cm, annot=True, fmt="g", mask=~off_diag_mask, cmap='Greens',vmin=vmin, vmax=vmax,ax=ax)
sns.heatmap(df_cm, annot=True, fmt="g", mask=off_diag_mask, cmap='gray_r',vmin=vmin, vmax=vmax,xticklabels=labels, yticklabels=labels)
ax.set_title('Confusion Matrix for Chest X-ray8 Dataset using Efficient Net b1');

# %%
plt.figure(figsize=(12,8))
ax= plt.subplot()
df_cm = np.array([[ 514,   27,    2],
        [   7, 1440,    6],
        [   2,    5,  195]])
vmin = np.min(df_cm)
vmax = np.max(df_cm)
off_diag_mask = np.eye(*df_cm.shape, dtype=bool)
labels = ['Covid', 'Normal', 'Viral']

sns.heatmap(df_cm, annot=True, fmt="g", mask=~off_diag_mask, cmap='Greens',vmin=vmin, vmax=vmax,ax=ax)
sns.heatmap(df_cm, annot=True, fmt="g", mask=off_diag_mask, cmap='gray_r',vmin=vmin, vmax=vmax,xticklabels=labels, yticklabels=labels)
ax.set_title('Confusion Matrix for Covid Pneumonia Dataset using Resnet');

# %%
plt.figure(figsize=(12,8))
ax= plt.subplot()
df_cm = np.array([[ 527,   16,    0],
        [   7, 1442,    4],
        [   0,    4,  198]])
vmin = np.min(df_cm)
vmax = np.max(df_cm)
off_diag_mask = np.eye(*df_cm.shape, dtype=bool)
labels = ['Covid', 'Normal', 'Viral']

sns.heatmap(df_cm, annot=True, fmt="g", mask=~off_diag_mask, cmap='Greens',vmin=vmin, vmax=vmax,ax=ax)
sns.heatmap(df_cm, annot=True, fmt="g", mask=off_diag_mask, cmap='gray_r',vmin=vmin, vmax=vmax,xticklabels=labels, yticklabels=labels)
ax.set_title('Confusion Matrix for Covid Pneumonia Dataset using MobileNet');

# %%
plt.figure(figsize=(12,8))
ax= plt.subplot()
df_cm = np.array([[ 527,   13,    3],
        [   7, 1443,    3],
        [   1,    3,  198]])
vmin = np.min(df_cm)
vmax = np.max(df_cm)
off_diag_mask = np.eye(*df_cm.shape, dtype=bool)
labels = ['Covid', 'Normal', 'Viral']

sns.heatmap(df_cm, annot=True, fmt="g", mask=~off_diag_mask, cmap='Greens',vmin=vmin, vmax=vmax,ax=ax)
sns.heatmap(df_cm, annot=True, fmt="g", mask=off_diag_mask, cmap='gray_r',vmin=vmin, vmax=vmax,xticklabels=labels, yticklabels=labels)
ax.set_title('Confusion Matrix for Covid Pneumonia Dataset using Efficient Net b1');

# %%
plt.figure(figsize=(12,8))
ax= plt.subplot()
df_cm = np.array([[226,   1,   9],
        [  8, 365,  44],
        [  5, 107, 112]])
vmin = np.min(df_cm)
vmax = np.max(df_cm)
off_diag_mask = np.eye(*df_cm.shape, dtype=bool)
labels = ['Normal', 'Pneumonia Bacteria', 'Pneumonia Viral']

sns.heatmap(df_cm, annot=True, fmt="g", mask=~off_diag_mask, cmap='Greens',vmin=vmin, vmax=vmax,ax=ax)
sns.heatmap(df_cm, annot=True, fmt="g", mask=off_diag_mask, cmap='gray_r',vmin=vmin, vmax=vmax,xticklabels=labels, yticklabels=labels)
ax.set_title('Confusion Matrix for Pneumonia Dataset using Resnet');

# %%
plt.figure(figsize=(12,8))
ax= plt.subplot()
df_cm = np.array([[220,   5,  11],
        [  5, 371,  41],
        [  3, 106, 115]])
vmin = np.min(df_cm)
vmax = np.max(df_cm)
off_diag_mask = np.eye(*df_cm.shape, dtype=bool)
labels = ['Normal', 'Pneumonia Bacteria', 'Pneumonia Viral']

sns.heatmap(df_cm, annot=True, fmt="g", mask=~off_diag_mask, cmap='Greens',vmin=vmin, vmax=vmax,ax=ax)
sns.heatmap(df_cm, annot=True, fmt="g", mask=off_diag_mask, cmap='gray_r',vmin=vmin, vmax=vmax,xticklabels=labels, yticklabels=labels)
ax.set_title('Confusion Matrix for Pneumonia Dataset using MobileNet');

# %%
plt.figure(figsize=(12,8))
ax= plt.subplot()
df_cm = np.array([[231,   1,   4],
        [  7, 353,  57],
        [  8,  92, 124]])
vmin = np.min(df_cm)
vmax = np.max(df_cm)
off_diag_mask = np.eye(*df_cm.shape, dtype=bool)
labels = ['Normal', 'Pneumonia Bacteria', 'Pneumonia Viral']

sns.heatmap(df_cm, annot=True, fmt="g", mask=~off_diag_mask, cmap='Greens',vmin=vmin, vmax=vmax,ax=ax)
sns.heatmap(df_cm, annot=True, fmt="g", mask=off_diag_mask, cmap='gray_r',vmin=vmin, vmax=vmax,xticklabels=labels, yticklabels=labels)
ax.set_title('Confusion Matrix for Pneumonia Dataset using Efficient Net b1');
