# %%
import matplotlib.pyplot as plt
linestyle_str = [
     ('solid', 'solid'),      # Same as (0, ()) or '-'
     ('dotted', 'dotted'),    # Same as (0, (1, 1)) or ':'
     ('dashed', 'dashed'),    # Same as '--'
     ('dashdot', 'dashdot')]  # Same as '-.'

linestyle_tuple = [
     ('loosely dotted',        (0, (1, 10))),
     ('dotted',                (0, (1, 1))),
     ('densely dotted',        (0, (1, 1))),
     ('long dash with offset', (5, (10, 3))),
     ('loosely dashed',        (0, (5, 10))),
     ('dashed',                (0, (5, 5))),
     ('densely dashed',        (0, (5, 1))),

     ('loosely dashdotted',    (0, (3, 10, 1, 10))),
     ('dashdotted',            (0, (3, 5, 1, 5))),
     ('densely dashdotted',    (0, (3, 1, 1, 1))),

     ('dashdotdotted',         (0, (3, 5, 1, 5, 1, 5))),
     ('loosely dashdotdotted', (0, (3, 10, 1, 10, 1, 10))),
     ('densely dashdotdotted', (0, (3, 1, 1, 1, 1, 1)))]
names = [0.001, 0.005, 0.01, 0.05, 0.1]
values = [0.9854, 0.9793,0.9793,0.9563,0.9793]
plt.scatter( [0.001, 0.005, 0.01, 0.05, 0.1], [0.9854, 0.9793,0.9793,0.9563,0.9793])
plt.axvline(x=0.001,linestyle=(0,(5,10)))
plt.axvline(x=0.005,linestyle=(0,(5,10)))
plt.axvline(x=0.01,linestyle=(0,(5,10)))
plt.axvline(x=0.05,linestyle=(0,(5,10)))
plt.axvline(x=0.1,linestyle=(0,(5,10)))
plt.xlabel('Learning Rate')
plt.ylabel('F1 Score')
plt.plot(names, values)
plt.show()
